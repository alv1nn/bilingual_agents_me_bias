# %% [markdown]
# # Visualize the results for the single agent setting

# %%
# IMPORTS 

import sys
sys.path.append("/Users/xxAlv1Nxx/Documents/01a Masters/05 CS/CS 428B Probabilistic Models of Cognition – Language/Project/pragmatic_agents_me_bias")
from ME_data_analysis_and_visualization_functions_bilingual import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Plot the rewards

# %% [markdown]
# ### Literal listener

# %%
# N=3, trained for 50 epochs
plot_rewards('L0', n=3, n_epochs=30)

# %%
# N=3, trained for 50 epochs
plot_rewards('L0', n=3, n_epochs=30)

# %%
# N=10, trained for 100 epochs
plot_rewards('L0', n=10, n_epochs=30)

# %% [markdown]
# ### Pragmatic Listener

# %%
# N=3, trained for 50 epochs
plot_rewards('L1', n=3, n_epochs=30)

# %%
# N=10, trained for 100 epochs
plot_rewards('L1', n=10, n_epochs=30)

# %%
# N=10, trained for 100 epochs
plot_rewards('L1', n=10, n_epochs=100)

# %% [markdown]
# ## Plot the average lexica
#
# Note that plotting the average lexica only makes sense in the single agent setting. In the two agent setting the state-message mapping is not predetermined and can differ between speaker-listener pairs so averaging does not make sense.

# %% [markdown]
# ### Literal Listener

# %%
plot_lexica_single_agent('L0')

# %% [markdown]
# ### Pragmatic Listener

# %%
plot_lexica_single_agent('L1')

# %%
save_all_lexica(blocked=0)

# %%
save_all_lexica(blocked=2, b=2)

# %%
save_all_lexica(blocked=2, b=4)

# %%
save_all_lexica(blocked=2, b=8)

# %%
save_all_lexica(blocked=2, b=16)

# %%
lexica_correl(blocked=1, b_array=[2])
# Out:
# 0.9986411036109598

# %%
lexica_correl(blocked=2, b_array=[2, 4, 8, 16])
# Out:
# 2	0.8361926417177272
# 4	0.9399212791137614
# 8	0.9686474384888833
# 16	0.9883629456737842

# %% [markdown]
# ## Plot the ME bias in form of bar plots

# %% [markdown]
# ### Literal listener

# %%
bar_plot_me_bias('L0')
# Out:
# 2021-11-25 08:43:52.461923: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Pragmatic listener

# %%
bar_plot_me_bias('L1')

# %%
save_all_test()

# %% [markdown]
# ## Calculate the ME Index
#
# See paper for definition of the ME index.

# %% [markdown]
# ### Literal listener

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L0')
# Out:
# N=3 K=1: -0.001 0.007
# N=3 K=2: -0.001 0.01
# N=10 K=1: 0.0 0.002
# N=10 K=2: 0.0 0.002

# %% [markdown]
# ### Pragmatic listener

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L1')
# Out:
# N=3 K=1: 0.998 0.001
# N=3 K=2: 0.999 0.0
# N=10 K=1: 0.848 0.188
# N=10 K=2: 0.998 0.003

# %% [markdown]
# ## Plot rewards and ME index over time
#
# These plots are only for the agents who were trained on all except one input, so K=1.

# %%
plot_rewards_me_index( \
    colors=['red','blue'], \
    plot_array=[ \
        {'n':3, 'blocked':0, 'b':1, 'reasoning':0, 'ablation':0, 'e_max': 26}, \
        {'n':3, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 26}], \
    legend_array=['literal reward', 'literal $I_{ME}$', 'pragmatic reward', 'pragmatic $I_{ME}$'], \
    rewards=1)

# %%
plot_rewards_me_index( \
    colors=['red','blue'], \
    plot_array=[ \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':0, 'ablation':0, 'e_max': 46}, \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 46}], \
    legend_array=['literal reward', 'literal $I_{ME}$', 'pragmatic reward', 'pragmatic $I_{ME}$'], \
    rewards=1)

# %%
plot_rewards_me_index( \
    colors=['red','blue'], \
    plot_array=[ \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':0, 'ablation':0, 'e_max': 100}, \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100}], \
    legend_array=['literal reward', 'literal $I_{ME}$', 'pragmatic reward', 'pragmatic $I_{ME}$'], \
    rewards=1)

# %%
plot_rewards_me_index( \
    colors = ['#3cf49c', '#13eac9', '#0dc5d0', '#0986b5', '#055199', '#022B88', '#0B0065', '#000030'], \
    plot_array=[{'n':i, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 50} for i in range(3, 11)], \
    legend_array=['n=' + str(i) for i in range(3, 11)], \
    rewards=0, print_breaks=True)
# Out:
# 3	max: NA;	min: NA
# 4	max: NA;	min: NA
# 5	max: 25;	min: NA
# 6	max: 17;	min: 45
# 7	max: 17;	min: 47
# 8	max: 14;	min: 44
# 9	max: 15;	min: 43
# 10	max: 15;	min: 47

# %%
plot_rewards_me_index( \
    colors = ['#3cf49c', '#13eac9', '#0dc5d0', '#0986b5', '#055199', '#022B88', '#0B0065', '#000030'], \
    plot_array=[{'n':i, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100} for i in range(20, 120, 20)], \
    legend_array=['n=' + str(i) for i in range(20, 120, 20)], \
    rewards=0, print_breaks=True)
# Out:
# 20	max: [20 29];	min: [28 31]
# 40	max: 26;	min: 36
# 60	max: [43 62 68 75 80];	min: [58 63 69 76 81]
# 80	max: [61 64 66 69 75 88 91];	min: [63 65 67 72 76 89 92]
# 100	max: 91;	min: 92

# %%
plot_rewards_me_index( \
    colors = ['blue', 'purple'], \
    plot_array=[ \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100}, \
        {'n':10, 'blocked':1, 'b':2, 'reasoning':1, 'ablation':0, 'e_max': 100}], \
    legend_array=['interleaved reward', 'interleaved $I_{ME}$', 'blocked reward', 'blocked $I_{ME}$'], \
    rewards=1, width=9)

# %%
plot_rewards_me_index( \
    colors = ['blue', 'purple'], \
    plot_array=[ \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100}, \
        {'n':10, 'blocked':2, 'b':2, 'reasoning':1, 'ablation':0, 'e_max': 100}], \
    legend_array=['interleaved reward', 'interleaved $I_{ME}$', 'blocked reward', 'blocked $I_{ME}$'], \
    rewards=1, width=9)

# %%
plot_rewards_me_index( \
    colors = ['#f1cc65', '#c8a397', '#9f7e9d', '#735b9b', '#3d3b96'], \
    plot_array=[{'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100}] + \
        [{'n':10, 'blocked':2, 'b':2**i, 'reasoning':1, 'ablation':0, 'e_max': 100} for i in range(1, 5)], \
    legend_array=['interleaved'] + [str(2**i) + ' blocks' for i in range(1, 5)], \
    rewards=0, width=9)

# %%
plot_rewards_me_index( \
    colors = ['teal', 'blue'], \
    plot_array=[\
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100, 'n_lang':1}, \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 100, 'n_lang':2}], \
    legend_array=['monolingual reward', 'monolingual $I_{ME}$', 'bilingual reward', 'bilingual $I_{ME}$'], \
    rewards=1, width=9)

# %%
plot_rewards_me_index( \
    colors = ['teal', 'blue'], \
    plot_array=[\
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 20, 'n_lang':1}, \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':0, 'e_max': 20, 'n_lang':2}], \
    legend_array=['monolingual reward', 'monolingual $I_{ME}$', 'bilingual reward', 'bilingual $I_{ME}$'], \
    rewards=1, width=9)

# %% [markdown]
# ## Ablation study results: ME index

# %% [markdown]
# ### Literal agents' lexica, pragmatic reasoning at test time

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L0', ablation=True)
# Out:
# N=3 K=1: 0.988 0.0
# N=3 K=2: 0.988 0.001
# N=10 K=1: 1.0 0.0
# N=10 K=2: 1.0 0.0

# %% [markdown]
# ### Pragmatic agents' lexica, literal reasoning at test time

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L1', ablation=True)
# Out:
# N=3 K=1: 0.421 0.011
# N=3 K=2: 0.473 0.008
# N=10 K=1: 0.543 0.046
# N=10 K=2: 0.504 0.017

# %% [markdown]
# ## Ablation study results: rewards and ME index over time
#
# **The legend shows the reasoning ability during training, the reasoning ability at test time was opposite!**

# %%
plot_rewards_me_index( \
    colors=['red','blue'], \
    plot_array=[ \
        {'n':3, 'blocked':0, 'b':1, 'reasoning':0, 'ablation':1, 'e_max': 26}, \
        {'n':3, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':1, 'e_max': 26}], \
    legend_array=['literal reward', 'literal $I_{ME}$', 'pragmatic reward', 'pragmatic $I_{ME}$'], \
    rewards=1)

# %%
plot_rewards_me_index( \
    colors=['red','blue'], \
    plot_array=[ \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':0, 'ablation':1, 'e_max': 41}, \
        {'n':10, 'blocked':0, 'b':1, 'reasoning':1, 'ablation':1, 'e_max': 41}], \
    legend_array=['literal reward', 'literal $I_{ME}$', 'pragmatic reward', 'pragmatic $I_{ME}$'], \
    rewards=1)
