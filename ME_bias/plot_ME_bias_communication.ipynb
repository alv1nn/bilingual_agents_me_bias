# %% [markdown]
# # Visualize the results for the two agent setting

# %%
# IMPORTS

import sys
# sys.path.append("/net/store/cogmod/users/xenohmer/Conferences/CogSci2020/pragmatic_agents_me_bias/")
sys.path.append(r"C:/Users/xenia/PycharmProjects/pragmatic_agents_me_bias/")
from ME_data_analysis_and_visualization_functions import *

# %% [markdown]
# ## Plot the rewards

# %% [markdown]
# ### Literal agents

# %%
# N=3, trained for 100 epochs
plot_rewards('L0_S0', n=3, n_epochs=100)

# %%
# N=10, trained for 1000 epochs
plot_rewards('L0_S0', n=10, n_epochs=1000)

# %% [markdown]
# ### Pragmatic listener

# %%
# N=3, trained for 100 epochs
plot_rewards('L1_S1', n=3, n_epochs=100)

# %%
# N=10, trained for 1000 epochs
plot_rewards('L1_S1', n=10, n_epochs=1000)

# %% [markdown]
# ## Plot the ME bias in form of bar plots

# %%
bar_plot_me_bias('L0_S0')

# %%
bar_plot_me_bias('L1_S1')

# %% [markdown]
# ## Calculate ME index
#
# See paper for definition of the ME index.

# %% [markdown]
# ### Literal speaker-listener pair

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L0_S0')
# Out:
# N=3 K=1: -0.5 0.0
# N=3 K=2: -2.0 0.0
# N=10 K=1: -0.111 0.0
# N=10 K=2: -0.25 0.0

# %% [markdown]
# ### Pragmatic speaker-listener pair

# %%
# N: total number of states and messages, K: number of messages excluded from training
me_index('L1_S1')
# Out:
# N=3 K=1: 0.991 0.002
# N=3 K=2: 0.964 0.116
# N=10 K=1: 0.842 0.259
# N=10 K=2: 0.84 0.179

# %% [markdown]
# ## Plot rewards  and ME index over time
#
# this takes quite some time (~15 minutes)

# %%
plot_rewards_plus_me_index_two_agents()
